# %% [markdown]
# ### **AULA 1 -- Python, Pandas e Pharmacia**

# %%
10 + 10
# Out:
# 20

# %%
"Alexsandro"
# Out:
# 'Alexsandro'

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados.tratamento.value_counts().plot.bar()

# %% [markdown]
# O Grupo com controle seria o grupo a ser comparado, tomado como parâmetro ou referência para as variaveis do local naquela hora, data e ambiente tendo as mesmas condições que o grupo com droga, exceto pelo fato da adição da droga, mas como está sendo estudado

# %% [markdown]
# Desafio 02: Plotar as 5 últimas linhas da tabela

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# Desafio 03: Proporção das classes tratamento.

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# Desafio 04: Quantos tipos de drogas foram investigados.

# %%
dados_comDrogras = dados[dados['tratamento']=='com_droga']
print(dados_comDrogras['droga'].unique())
print(len(dados_comDrogras['droga'].unique()))
# Out:
# ['b68db1d53' 'df89a8e5a' '18bb41b2c' ... '573c787a2' 'b2fe3eca7'
#  'dd4a96d16']
# 3288

# %% [markdown]
# Desafio 05: Procurar na documentação método query(pandas)

# %% [markdown]
# O método query pode ser usado para requisões mais simples de sintaxe na linguagem python

# %%
dados.query('tratamento == "com_droga"')
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23808  id_fff8c2444  com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed  com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c  com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23812  id_fffcb9e7c  com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b  com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# ...

# %% [markdown]
# Desafio 06: Renomear as colunas tirando o hífen

# %%
colunas = dados.columns[5:]
for i in range(len(colunas)):
  x = colunas[i].split('-')
  separador = ''
  name = separador.join(x)
  dados.rename(columns={colunas[i]:name},inplace=True)

##ou :
##dados_modificado = dados.copy()
##dados_modificado.columns = [column.replace("-", "") for column in dados_modificado.columns]
##dados_modificado

dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Desafio 07: Gráficos bonitos

# %%
import matplotlib.pyplot as plt
dados['tempo'].value_counts().plot.bar()
plt.xlabel('Horario')
plt.ylabel('Quantidade')
plt.title("Quantidade por tempo")
# Out:
# Text(0.5, 1.0, 'Quantidade por tempo')

# %% [markdown]
# Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# Da base de dados pude aprender que terá que de alguma forma fazer um comparativo com os dados de tratamento com droga com o com controle para obter as informações previstas para o resultado. Há uma norma seguida GRP para estudo dos genomas. Mas precisamos nos aprofundar mais no dataset

# %% [markdown]
# ## **AULA 2 -- Estatística, dados e Distribuição**

# %% [markdown]
# A droga não é de fato um medicamento, mas são pequenas células ou moléculas que estão testando em massa para ver se sai algum resultado. Então vamos renomear a coluna

# %%
mapa = {'droga':'composto'}
dados.rename(columns = mapa, inplace = True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %% [markdown]
# o arromba é para indicar que é algo fora da array e o in é pq é uma lista

# %%
dat_order = dados.query('composto in @cod_compostos')

# %% [markdown]
# Desafio 1:ordenar o gráfico com countplot
# Desafio 2:Melhorar a visualização alterando tamanho da fonte, titulo

# %%
import seaborn as sns
import matplotlib.pyplot as plt

##o seaborn está com bug com o colab (atualização) ae precisa do set
sns.set()

plt.figure(figsize=(8,6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'),
              order = dat_order['composto'].value_counts().index
              )##.set_title('Top 5 Compostos') é uma forma ou armazena em 'ax'

ax.set_title('Top 5 Compostos em ordem decrescente', fontsize = 20)

plt.xlabel("Compostos",fontsize=16)
plt.ylabel("Quantidade", fontsize=16)

plt.show()

# %%
len(dados['g0'].unique())
# Out:
# 14367

# %%
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].max()
# Out:
# 10.0

# %% [markdown]
# Desafio 3: Plotar os histogramas

# %%
dados['g0'].hist(bins = 50)

# %%
dados['g0'].mean()
# Out:
# 0.24836629293692816

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %% [markdown]
# Desafio 4: estudar estatísticas retomadas no .describe()

# %% [markdown]
# Os quartis: 25%, 50% e 75% são os valores nos quais aquela porcentagem da quantidade de dados estão dispostos em ordem crescente, ou seja, divindo a quantidade de dados em 4 partes identicas e numericamente mostra-se qual é o maior valor dentro a tal segmentação.

# %%
dados[['g0','g1']]
# Out:
#            g0      g1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
#loc[linha, coluna]
#slice é 0:
dados.loc[:,'g0':'g771'].describe()
# Out:
#                  g0            g1  ...          g770          g771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
#quero fazer o histograma das médias mas para isso precisamos transpor a matriz
dados.loc[:,'g0':'g771'].describe().T
# Out:
#         count      mean       std     min       25%      50%       75%     max
# g0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...       ...       ...       ...     ...       ...      ...       ...     ...
# g767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# [772 rows x 8 columns]

# %%
dados.loc[:,'g0':'g771'].describe().T['mean'].hist(bins=30)

# %%
dados.loc[:,'g0':'g771'].describe().T['min'].hist(bins=30)

# %%
dados.loc[:,'g0':'g771'].describe().T['max'].hist(bins=30)

# %%
dados.loc[:,'c0':'c99'].describe().T['mean'].hist(bins=30)

# %%
dados.loc[:,'c0':'c99'].describe().T['min'].hist(bins=30)

# %%
dados.loc[:,'c0':'c99'].describe().T['max'].hist(bins=30)

# %%
sns.boxplot(x='g0',data=dados)

# %%
sns.boxplot(x='g0', y ='tratamento',data=dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot( x ='tratamento',y='g0',data=dados)

# %% [markdown]
# Desafio 5: Refletir sobre a manipulação dos tamanhos das visualizações

# %% [markdown]
# A com_droga há muitos valores outliers pelo fato de haver diferentes tipos de experimentos representado neste boxplot no qual estão todos dispostos graficamente juntos, assim, os outliers na verdade não são valores a serem descartados mas sim estudados para saber estudar cada experimento e compara-lo com o correto, a principio o com_controle, mas não se sabe se o com_controle.

# %% [markdown]
# Desafio 06: Fazer outras análises com o boxplot e até com o histograma

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
fig.suptitle('Distribuição de Genicas',fontdict= {'size':20}, weight='bold')
fig. tight_layout(pad=3.0)

ax1.set_title('g0')
ax1.hist(dados['g0'], bins = 50)
ax2.set_title('g19')
ax2.hist(dados['g19'], bins = 50)

ax1.xaxis.set_label_text('Compostos',fontdict= {'size':14}, weight='bold')
ax1.yaxis.set_label_text('Quantidade',fontdict= {'size':14}, weight='bold')

ax2.xaxis.set_label_text('Compostos',fontdict= {'size':14}, weight='bold')
ax2.yaxis.set_label_text('Quantidade',fontdict= {'size':14}, weight='bold')

plt.show()

# %%
sns.set()
fig, ax = plt.subplots(figsize=(8,6))
ax.xaxis.set_label_text('Compostos',fontdict= {'size':14}, weight='bold')
ax.yaxis.set_label_text('Quantidade',fontdict= {'size':14}, weight='bold')

sns.histplot(data=dados, x='g0', ax=ax, color="purple")
sns.histplot(data=dados,x='g20', ax=ax, color="orange")

plt.show()

# %% [markdown]
# ### **AULA 3: Correlações e causalidade**

# %%
##Tabela de frequência (mas está misturado oq recebeu composto e oq não)
pd.crosstab(dados['dose'],dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'],normalize=True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'],normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g0', 'g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='g0',y='g8',data=dados)

# %%
sns.lmplot(data=dados, x='g0',y='g8',line_kws={'color':'red'})

# %%
sns.lmplot(data=dados, x='g0',y='g8',line_kws={'color':'red'}, col='tratamento',row='tempo')

# %%
dados.loc[:,'g0':'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
corr = dados.loc[:,'g0':'g50'].corr()

# %% [markdown]
# A correlação não implica em causalidade, ou seja, há um comportamento entre os parâmetros mas não necessáriamente este é a unica causa deste comportamento

# %%
import numpy as np

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Os valores na coluna C dizem a respeito da viabilidade celular, ou seja, quantas celulas sobreviveram a aquele experimento.

# %%
corr_celular = dados.loc[:,'c0':'c50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Desafio 1: Criar tablea de frequência com pandas.groupby

# %%
dados.groupby(['dose','tempo'],observed=True).size()
# Out:
# dose  tempo
# D1    24       3886
#       48       4354
#       72       3907
# D2    24       3886
#       48       3896
#       72       3885
# dtype: int64

# %% [markdown]
# Desafio 2: Normalizar o crosstab pela coluna

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'],normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# Desafio 03: Testar outros agregadores

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='median')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24          -0.2912    0.02700
#      48          -0.2145    0.01620
#      72          -0.3655    0.02615
# D2   24           0.0096   -0.02610
#      48          -0.0506   -0.02960
#      72           0.0528    0.00015

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='min')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           -2.370     -5.183
#      48           -3.276     -5.420
#      72           -2.086     -5.261
# D2   24           -2.135     -5.233
#      48           -4.859     -4.567
#      72           -1.909     -5.513

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='max')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.226      9.908
#      48            3.423     10.000
#      72            2.584      9.355
# D2   24            2.601      7.167
#      48            4.335     10.000
#      72            4.670     10.000

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='max')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.226      9.908
#      48            3.423     10.000
#      72            2.584      9.355
# D2   24            2.601      7.167
#      48            4.335     10.000
#      72            4.670     10.000

# %% [markdown]
# Desafio 04: Explorar o melt

# %% [markdown]
# essa função dilui a tabela de colunas para linhas

# %%
dados.melt(id_vars= ['tratamento','id','tempo','dose'] )
# Out:
#             tratamento            id  tempo dose  variable      value
# 0            com_droga  id_000644bb2     24   D1  composto  b68db1d53
# 1            com_droga  id_000779bfc     72   D1  composto  df89a8e5a
# 2            com_droga  id_000a6266a     48   D1  composto  18bb41b2c
# 3            com_droga  id_0015fd391     48   D1  composto  8c7f86626
# 4            com_droga  id_001626bd3     72   D2  composto  7cbed3131
# ...                ...           ...    ...  ...       ...        ...
# 20789617     com_droga  id_fffb1ceed     24   D2       c99      0.468
# 20789618     com_droga  id_fffb70c0c     24   D2       c99     0.3689
# 20789619  com_controle  id_fffc1c3f4     48   D2       c99     0.3808
# 20789620     com_droga  id_fffcb9e7c     24   D1       c99      0.074
# 20789621     com_droga  id_ffffdd77b     72   D1       c99     -4.252
#
# [20789622 rows x 6 columns]

# %% [markdown]
# Desafio 5: Calcular e analisar as correlações genicas e celulares

# %%
corr_c_g = dados.loc[:, 'g0':'g50'].merge(dados.loc[:, 'c0':'c50'], on=dados['id']).corr().loc['g0':'g50', "c0":'c50']
corr_c_g.head()
# Out:
#           c0        c1        c2  ...       c48       c49       c50
# g0 -0.624116 -0.624810 -0.639789  ... -0.595291 -0.609109 -0.594011
# g1 -0.037405 -0.030558 -0.039616  ... -0.006228  0.027230  0.017267
# g2 -0.168656 -0.178692 -0.176733  ... -0.160305 -0.167884 -0.153191
# g3 -0.037342 -0.093505 -0.085298  ... -0.058527 -0.033818 -0.012714
# g4 -0.403545 -0.379840 -0.392841  ... -0.349730 -0.349804 -0.360544
#
# [5 rows x 51 columns]

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_c_g, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_c_g, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# #Desafio 6
# O heatmap pode ser usado para muitas aplicações, não apenas correlações, mas para aplicações assim como design que mostra onde o cursor do mouse ou pelo webcam, vendo onde a pessoa olhou, primeiro entre outras coisas, assim como mapa de casos de covid no brasil utilizando apis do mapa do google para o fundo geográfica. É uma ferramenta poderosa para insights bons para iniciar teorias para explorar

# %% [markdown]
# #Desafio 7
# O avanço do conhecimento dos dados é bem exponencial, apesar de nenhuma confirmação conclusiva fomentada ainda há muitos indícios bons para serem explorados principalmente com este mapa de calor, e a forma que cada gen tem correlação identica para cada célula

# %% [markdown]
# ### **Aula 4**

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersao-dados-desafio-final/blob/main/Dados/dados_resultados.csv?raw=true')

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_drop = dados_resultados.drop('id',axis=1).sum().sort_values(ascending=False)
contagem_drop
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %% [markdown]
# Soma dos mecanismos de ação, ou seja, a soma do dataset por linha

# %%
dados_resultados.drop('id',axis=1).sum(axis = 1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %% [markdown]
# quer dizer, que cada experimento há ativação de nenhum, 1 ou mais que 1 mecanismos

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id',axis=1).sum(axis = 1)
#se rodar mais de uma vez ele vai somando em cima da coluna n_moa, soma em cima da soma

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa','ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %% [markdown]
# Queria averiguar se realmente todas os experimentos que foram feitos sem drogas, ou seja, com controle realmente não tiverem a ativação de nenhuma mecanismo (oq é esperado)

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y='g0',x='composto', hue='ativo_moa')

# %% [markdown]
# Desafio 1: Encontrar o top 10 das ações do MOA(inibidor, agonista...)

# %%
ordenado=[]
for i in contagem_drop.index:
  ordenado.append(i.split('_')[-1])

contagem = pd.DataFrame({'Qtd':contagem_drop.values}, index = ordenado).groupby(by = ordenado).sum().sort_values(by='Qtd', ascending=False).head(10)

contagem
# Out:
#                     Qtd
# inhibitor          9693
# antagonist         3449
# agonist            2330
# blocker             323
# agent               150
# activator           115
# local                80
# antioxidant          73
# anti-inflammatory    73
# immunosuppressant    73

# %% [markdown]
# Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle

# %%
dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == 'com_controle')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c99  n_moa  ativo_moa  eh_controle
# 0  id_000644bb2  com_droga     24   D1  ...  0.4176      1       True        False
# 1  id_000779bfc  com_droga     72   D1  ...  0.7371      0      False        False
# 2  id_000a6266a  com_droga     48   D1  ...  0.6931      3       True        False
# 3  id_0015fd391  com_droga     48   D1  ... -0.8154      0      False        False
# 4  id_001626bd3  com_droga     72   D2  ...  0.7125      1       True        False
#
# [5 rows x 880 columns]

# %% [markdown]
# Desafio 03: Crirar 3 colunas booleanas para cada tempo 24, 48, 72

# %%
dados_combinados['24'] = (dados_combinados['tempo'] == 24)
dados_combinados['48'] = (dados_combinados['tempo'] == 48)
dados_combinados['72'] = (dados_combinados['tempo'] == 72)

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... eh_controle     24     48     72
# 0  id_000644bb2  com_droga     24   D1  ...       False   True  False  False
# 1  id_000779bfc  com_droga     72   D1  ...       False  False  False   True
# 2  id_000a6266a  com_droga     48   D1  ...       False  False   True  False
# 3  id_0015fd391  com_droga     48   D1  ...       False  False   True  False
# 4  id_001626bd3  com_droga     72   D2  ...       False  False  False   True
#
# [5 rows x 883 columns]

# %% [markdown]
# Desafio 4: Estudar sobre combinações de DF, merge, join...

# %% [markdown]
# merge
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html?highlight=merge#pandas.DataFrame.merge
#
# join
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html#pandas.DataFrame.join

# %% [markdown]
# Desafio 05: Escolher 1 droga e fazer analise mais detalhada considerando tempo e dose, para comparar as distribuições e dps comparar com o CONTROLE

# %%
composto_analise = dados_combinados.query('composto == "87d714366"')

composto_analise
# Out:
#                  id tratamento  tempo dose  ... eh_controle     24     48     72
# 16     id_002fb9c19  com_droga     48   D1  ...       False  False   True  False
# 76     id_00cf039a7  com_droga     48   D2  ...       False  False   True  False
# 119    id_01534c4ee  com_droga     72   D2  ...       False  False  False   True
# 209    id_0236e3425  com_droga     72   D1  ...       False  False  False   True
# 218    id_024a52260  com_droga     24   D2  ...       False   True  False  False
# ...             ...        ...    ...  ...  ...         ...    ...    ...    ...
# 23680  id_fe8abffe0  com_droga     72   D1  ...       False  False  False   True
# 23727  id_ff1d43f96  com_droga     24   D2  ...       False   True  False  False
# 23776  id_ff9d0a022  com_droga     24   D2  ...       False   True  False  False
# 23791  id_ffd1fd119  com_droga     72   D2  ...       False  False  False   True
# 23802  id_fff3976bd  com_droga     24   D1  ...       False   True  False  False
#
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize = (15, 10), sharey = True)

sns.boxplot(ax = axes[0], data = composto_analise, x = 'composto', y = 'g0', hue = 'tempo')
sns.boxplot(ax = axes[1], data = composto_analise, x = 'composto', y = 'g0', hue = 'dose')
plt.show()

# %%
corr_c_g = composto_analise.loc[:, 'g0':'g50'].merge(composto_analise.loc[:, 'c0':'c50'], on=composto_analise['id']).corr().loc['g0':'g50', "c0":'c50']
corr_c_g.head()
# Out:
#           c0        c1        c2  ...       c48       c49       c50
# g0 -0.471756 -0.343061 -0.429729  ... -0.359767 -0.366251 -0.423998
# g1  0.219892  0.335961  0.196420  ...  0.200913  0.357269  0.276867
# g2  0.060218  0.032365  0.059501  ... -0.034282 -0.001642  0.053936
# g3  0.555633  0.351487  0.488316  ...  0.492048  0.519993  0.579653
# g4 -0.503531 -0.267899 -0.420313  ... -0.491765 -0.400767 -0.486186
#
# [5 rows x 51 columns]

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_c_g, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_c_g, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
print(dados_combinados['composto'].value_counts())
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 23458e56a       1
# 263b9a195       1
# 7b1ac15fc       1
# 82dcdb180       1
# 8bc88a3be       1
# Name: composto, Length: 3289, dtype: int64

# %%
fig, axs = plt.subplots(1,2,figsize=(20,8), sharey=True)

composto_principal = dados_combinados['composto'].value_counts().index[1:2]

sns.boxplot(data=composto_analise, x='tempo', y='g0', hue='dose',ax=axs[0])
axs[0].set_title(f"{composto_analise['composto'][1:2]}")


composto_principal = dados_combinados.query('tratamento == "com_controle"')['composto'].value_counts().index[0]
sns.boxplot(data=dados_combinados.query('composto in @composto_principal'), x='tempo', y='g0', hue='dose',ax=axs[1])

axs[1].set_title(f"{composto_principal} (controle)")
axs[1].set_ylabel("")
plt.show()

# %%
dados_combinados['composto'].value_counts().index[1:2]
# Out:
# Index(['87d714366'], dtype='object')

# %% [markdown]
# Desafio 06: Descibrir se tem algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA

# %%
x = dados_combinados.query('composto == "dd4a96d16"')

print(x['composto'])
# Out:
# 23757    dd4a96d16
# Name: composto, dtype: object

# %%
from tqdm import tqdm


droga = dados_combinados['composto'].unique()
target = []
for i in tqdm(droga):
  x = dados_combinados.query('composto == @i')
  if(len(x['n_moa'].unique()) > 1):
    target.append(i)

print(f'\n\n {target}')
# Out:
# 100%|██████████| 3289/3289 [01:16<00:00, 43.25it/s]
#  []

# %% [markdown]
# Desafio 07: Descobrir se tem algum composto que dependendo da configuração ativa MOA's diferentes

# %%
droga = dados_combinados['composto'].unique()
target = []
for i in tqdm(droga):
  x = dados_combinados.query('composto == @i')
  if(len(x['ativo_moa'].unique()) > 1):
    target.append(i)

print(f'\n\n {target}')
# Out:
# 100%|██████████| 3289/3289 [01:16<00:00, 43.20it/s]
#  []

# %% [markdown]
# ### **AULA 5**

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... eh_controle     24     48     72
# 0  id_000644bb2  com_droga     24   D1  ...       False   True  False  False
# 1  id_000779bfc  com_droga     72   D1  ...       False  False  False   True
# 2  id_000a6266a  com_droga     48   D1  ...       False  False   True  False
# 3  id_0015fd391  com_droga     48   D1  ...       False  False   True  False
# 4  id_001626bd3  com_droga     72   D2  ...       False  False  False   True
#
# [5 rows x 883 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split


x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']

#random_state faz a separação nesta seed
#stratify faz a separação mais fiel a proporção das classes
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.2, stratify=y ,random_state = 376)

#STOP: TOTAL NO. of ITERATIONS REACHED LIMIT. apareceu então tem que colocar o max_iter maximo de iterações
modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6267058576527399

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')

modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %%
dados_combinados['ativo_moa'].value_counts(normalize=True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.2, stratify=y ,random_state = 376)

modelo_arvore = DecisionTreeClassifier(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6105395758975436

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize=(15,10), facecolor='k')
tree.plot_tree(modelo_arvore,
               ax=ax,
               fontsize=10,
               rounded=True,
               filled=True,
               feature_names=x_treino.columns,
               class_names=["Não ativado", "Ativado"])

plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.2, stratify=y ,random_state = 376)

teste=[]
treino=[]
for i in range(1,15):
    modelo_arvore = DecisionTreeClassifier(max_depth = i)
    modelo_arvore.fit(x_treino, y_treino)
    teste.append(modelo_arvore.score(x_teste, y_teste))
    treino.append(modelo_arvore.score(x_treino, y_treino))

# %%
teste

# %%
treino

# %%
sns.lineplot(x = range(1,15), y = teste, label='teste')
sns.lineplot(x = range(1,15), y = treino, label='treino')

# %%
#from sklearn.ensemble import RandomForestClassifier

#x = dados_combinados.drop(['id','n_moa','ativo_moa'], axis=1)
#y = dados_combinados['ativo_moa']
#x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.2, stratify=y ,random_state = 376)
#
#
#modelo_randomforest = RandomForestClassifier(max_depth = i)
#modelo_randomforest.fit(x_treino, y_treino)
#modelo_randomforest.score(x_teste, y_teste)

# %% [markdown]
# Não foi possivel usar a coluna de tratamento pois é uma string, droparemos ela, e converteremos para colunas diferentes binárias

# %%
#Aqui ele coloca as classes em colunas de 0 e 1
pd.get_dummies(dados_combinados['tratamento'])

# %%
pd.get_dummies(dados_combinados, columns=['tratamento','dose','tempo'])

# %%
dados_combinados.drop(['id','n_moa','ativo_moa','composto','24','48','72','eh_controle'], axis=1)

# %%
from sklearn.neighbors import KNeighborsClassifier

x = dados_combinados.drop(['id','n_moa','ativo_moa','composto','24','48','72','eh_controle'], axis=1)
x = pd.get_dummies(x, columns=['tratamento','dose','tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.2, stratify=y ,random_state = 376)

teste_knn = []
treino_knn = []


knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(x_treino, y_treino)
knn.score(x_teste, y_teste)
knn.score(x_treino, y_treino)

# %%
teste_knn

# %%
treino_knn

# %%
sns.lineplot(x = range(len(teste_knn)), y = teste_knn, label='teste')
sns.lineplot(x = range(len(treino_knn)), y = treino_knn, label='treino')

# %% [markdown]
# ###Desafio 01: Tente outros modelos ou mude os parÂmetros dos modelos que
#
#
# testamos em aula
#
# ###Desafio 02: Estude a documentação do Sklearn
#
# ###Desafio 03: Pesquisar o fluxograma 'Escolhendo o melhor modelo'
#
# https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html
#
# ###Desafio 04: Teste outras perguntas de classificação: 0, 1 ou +
#
# ###Desafio 05: Escolha outra variável
#
# ###Desafio 06: Resumo do que fizemos

# %% [markdown]
# Desafio 01

# %%
 from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)

x = dados_combinados.drop(['id','n_moa','ativo_moa','composto','24','48','72','eh_controle'], axis=1)
#x = pd.get_dummies(x, columns=['tratamento','dose','tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.2, stratify=y ,random_state = 376)
knn.fit(x_treino, y_treino)


sns.lineplot(x = range(1,15), y = teste, label='teste')
sns.lineplot(x = range(1,15), y = treino, label='treino')
